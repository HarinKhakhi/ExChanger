# %%
# -*- coding: utf-8 -*-
"""extract_faces.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1n94ly5DXYIAb4UqV0DOZn9QKlqKTH1-y
"""

from cv2 import imread

from cv2 import waitKey
from cv2 import destroyAllWindows
from cv2 import CascadeClassifier
from cv2 import rectangle
import cv2
import cv2

import numpy as np
# load the pre-trained model
classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# load the photograph
pixels = cv2.imread("photo.jpg")

recs = classifier.detectMultiScale(pixels)

print( dict(np.ndenumerate(recs)))
# Out:
# {(0, 0): 31, (0, 1): 57, (0, 2): 143, (0, 3): 143}

# %%
ret = {}
cnt = 0
for box in bboxes:
    ret['box'+str(cnt)] = box
    cnt+=1

# %%
print(ret)
# Out:
# {'box0': array([ 31,  57, 143, 143], dtype=int32)}
